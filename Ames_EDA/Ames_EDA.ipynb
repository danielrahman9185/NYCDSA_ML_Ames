# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\PokeG\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
price = pd.read_csv('Ames_HousePrice.csv')

# %%
pd.set_option('display.max_columns', 82)
price.head()
# Out:
#    Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0           1  909176150        856     126000          30       RL
# 1           2  905476230       1049     139500         120       RL
# 2           3  911128020       1001     124900          30  C (all)
# 3           4  535377150       1039     114000          70       RL
# 4           5  534177230       1665     227000          60       RL
#
#    LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig  \
# 0          NaN     7890   Pave   NaN      Reg         Lvl    AllPub    Corner
# 1         42.0     4235   Pave   NaN      Reg         Lvl    AllPub    Inside
# 2         60.0     6060   Pave   NaN      Reg         Lvl    AllPub    Inside
# 3         80.0     8146   Pave   NaN      Reg         Lvl    AllPub    Corner
# 4         70.0     8400   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# ...

# %%
# Removing the outlier on the column 'GrLivArea'

price = price.loc[price["GrLivArea"] != 4676]

# %%
len(price.columns)
price.shape
# Out:
# (2579, 82)

# %%
pd.set_option("display.max_columns" , None)
null_price = price.isnull().sum().to_frame()
null_price.T
# Out:
#    Unnamed: 0  PID  GrLivArea  SalePrice  MSSubClass  MSZoning  LotFrontage  \
# 0           0    0          0          0           0         0          462
#
#    LotArea  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0        0       0   2411         0            0          0          0
#
#    LandSlope  Neighborhood  Condition1  Condition2  BldgType  HouseStyle  \
# 0          0             0           0           0         0           0
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  \
# 0            0            0          0             0          0         0
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0            0            0          14          14          0          0
#
#    Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  \
# 0           0        69        69            71            69           1
#
# ...

# %%
price.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'PID'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>,
#         <AxesSubplot:title={'center':'SalePrice'}>,
#         <AxesSubplot:title={'center':'MSSubClass'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>],
#        [<AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'OverallCond'}>,
#         <AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'YearRemodAdd'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>],
#        [<AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF2'}>,
#         <AxesSubplot:title={'center':'BsmtUnfSF'}>,
#         <AxesSubplot:title={'center':'TotalBsmtSF'}>,
#         <AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>],
# ...

# %%
pd.set_option("display.max_columns" , None)
price.describe()
# Out:
#         Unnamed: 0           PID    GrLivArea      SalePrice   MSSubClass  \
# count  2579.000000  2.579000e+03  2579.000000    2579.000000  2579.000000
# mean    436.529275  7.147550e+08  1484.803024  178057.029081    57.690965
# std     258.867852  1.886608e+08   484.688461   75045.524426    42.810381
# min       1.000000  5.263011e+08   334.000000   12789.000000    20.000000
# 25%     215.500000  5.313630e+08  1112.000000  129950.000000    20.000000
# 50%     431.000000  5.354542e+08  1436.000000  159900.000000    50.000000
# 75%     645.500000  9.071806e+08  1733.000000  209750.000000    70.000000
# max    1000.000000  1.007100e+09  4316.000000  755000.000000   190.000000
#
#        LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  2117.000000    2579.000000  2579.000000  2579.000000  2579.000000
# mean     68.487010   10108.531214     6.044591     5.618845  1970.299729
# std      22.802067    8107.040427     1.365636     1.122159    29.716682
# ...

# %%
size_related = price.filter(regex='SF$|Area$')
size_related = size_related.fillna(0.0)

import seaborn as sns
corr = pd.concat([size_related, price['SalePrice']], axis=1).corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr_v_sp = price.corr().SalePrice.sort_values(ascending=False)
corr_v_sp
# Out:
# <ipython-input-10-5882402a559a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_v_sp = price.corr().SalePrice.sort_values(ascending=False)
# SalePrice        1.000000
# OverallQual      0.791687
# GrLivArea        0.725781
# TotalBsmtSF      0.655263
# 1stFlrSF         0.645961
# GarageCars       0.639100
# GarageArea       0.635422
# YearBuilt        0.544489
# FullBath         0.535624
# GarageYrBlt      0.520901
# YearRemodAdd     0.514408
# MasVnrArea       0.502223
# TotRmsAbvGrd     0.490977
# Fireplaces       0.488199
# BsmtFinSF1       0.462254
# LotFrontage      0.359061
# WoodDeckSF       0.333251
# OpenPorchSF      0.308131
# BsmtFullBath     0.291110
# HalfBath         0.285918
# LotArea          0.275043
# 2ndFlrSF         0.263457
# BsmtUnfSF        0.167513
# BedroomAbvGr     0.151801
# ...

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x='OverallQual', y='SalePrice', data=price, palette='GnBu')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
price.plot.scatter(x='GrLivArea', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
price.plot.scatter(x='TotalBsmtSF', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
price.plot.scatter(x='1stFlrSF', y='SalePrice')
price.head()
# Out:
#    Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0           1  909176150        856     126000          30       RL
# 1           2  905476230       1049     139500         120       RL
# 2           3  911128020       1001     124900          30  C (all)
# 3           4  535377150       1039     114000          70       RL
# 4           5  534177230       1665     227000          60       RL
#
#    LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig  \
# 0          NaN     7890   Pave   NaN      Reg         Lvl    AllPub    Corner
# 1         42.0     4235   Pave   NaN      Reg         Lvl    AllPub    Inside
# 2         60.0     6060   Pave   NaN      Reg         Lvl    AllPub    Inside
# 3         80.0     8146   Pave   NaN      Reg         Lvl    AllPub    Corner
# 4         70.0     8400   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# ...

# %%
price.plot.scatter(x='GarageArea', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
price['SalePrice'].hist(bins=75, rwidth=.8, figsize=(14,4))
#skewed right distribution with outliers (expensive houses)
# Out:
# <AxesSubplot:>

# %%
#create a heat map to see the multicollinearity between independent variables
#we see four pairs that stand out
x_no_price = price.loc[:, ~price.columns.isin(['SalePrice'])]
corr_mat = x_no_price.iloc[:, :-1].corr()
high_corr_mat = corr_mat[abs(corr_mat) >= 0.5]

plt.figure(figsize=(15, 10))
sns.heatmap(high_corr_mat,
            annot=True,
            fmt='.1f',
            cmap='PuRd',
            vmin=0.5,
            vmax=1)
title = plt.title('Independent Variables Correlation Heatmap')
# Out:
# <ipython-input-17-40b868edb2c7>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat = x_no_price.iloc[:, :-1].corr()
